# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
from stackapi import StackAPI
site = StackAPI('stackoverflow')
comments = SITE.fetch('comments')

# %%
# your code here
import pandas as pd
import matplotlib.pyplot as plt
import wbgapi as wb

# %%
wb.source.info()
wb.region.info()
wb.economy.info()

wb.series.info()

# %%
wb.series.info(q="financial")

# %%
business = wb.data.DataFrame('IC.REG.DURS', wb.region.members('ECS'))
business

# %%
ren = wb.data.DataFrame('IC.REG.DURS', ['FRA','UKR','EST'], time=range(2003,2019))
ren

# %%
ren.plot.bar()

# %%
g5.T.plot(ax=ax, figsize=(15,5))

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')

questions = SITE.fetch('questions')
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 55,
#  'total': 0,
#  'items': [{'tags': ['c#', 'datetime-format'],
#    'owner': {'reputation': 55,
#     'user_id': 19139299,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJzxcUIXlTUZGfHTiFYB48nA-NBwgdyuS7XTGL_m=k-s256',
#     'display_name': 'Tar270',
#     'link': 'https://stackoverflow.com/users/19139299/tar270'},
#    'is_answered': False,
#    'view_count': 46,
#    'answer_count': 2,
#    'score': -1,
#    'last_activity_date': 1681916021,
#    'creation_date': 1681912188,
#    'last_edit_date': 1681913926,
#    'question_id': 76055326,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/76055326/system-formatexception-string-638143033743100000-was-not-recognized-as-a-vali',
#    'title': 'System.FormatException: String &#39;638143033743100000&#39; was not recognized as a valid DateTime'},
# ...

# %%
# your code here
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')

questions = SITE.fetch('questions',fromdate = 1457136000, today = 14572224000, min = 20, tagged = 'python', sort = 'votes')

# %%
questions['items']
# Out:
# [{'tags': ['c#', 'datetime-format'],
#   'owner': {'reputation': 55,
#    'user_id': 19139299,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJzxcUIXlTUZGfHTiFYB48nA-NBwgdyuS7XTGL_m=k-s256',
#    'display_name': 'Tar270',
#    'link': 'https://stackoverflow.com/users/19139299/tar270'},
#   'is_answered': False,
#   'view_count': 46,
#   'answer_count': 2,
#   'score': -1,
#   'last_activity_date': 1681916021,
#   'creation_date': 1681912188,
#   'last_edit_date': 1681913926,
#   'question_id': 76055326,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/76055326/system-formatexception-string-638143033743100000-was-not-recognized-as-a-vali',
#   'title': 'System.FormatException: String &#39;638143033743100000&#39; was not recognized as a valid DateTime'},
#  {'tags': ['python', 'google-analytics', 'streamlit'],
#   'owner': {'reputation': 161,
#    'user_id': 5072832,
#    'user_type': 'registered',
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
answers = SITE.fetch("answers")
answers

# %%
SITE = StackAPI('stackoverflow')
most_voted = SITE.fetch('questions', fromdate=1638877910, today=1638877910, min=5, tagged='python', sort='votes')
most_voted
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 41,
#  'total': 0,
#  'items': [{'tags': ['python', 'python-black'],
#    'owner': {'reputation': 10765,
#     'user_id': 10036039,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6525d104fc1903b759afa7a7ff40cf22?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'zerocewl',
#     'link': 'https://stackoverflow.com/users/10036039/zerocewl'},
#    'is_answered': True,
#    'view_count': 67001,
#    'accepted_answer_id': 71674345,
#    'answer_count': 6,
#    'score': 160,
#    'last_activity_date': 1679491903,
#    'creation_date': 1648626375,
#    'last_edit_date': 1651785651,
#    'question_id': 71673404,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71673404/importerror-cannot-import-name-unicodefun-from-click',
#    'title': 'ImportError: cannot import name &#39;_unicodefun&#39; from &#39;click&#39;'},
# ...

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('answers', ids = [6784, 6473, 6778])
answers
