# %%
import re
names = []

for dev in soup.find_all('h1', {'class': 'h3 lh_condensed'}):
    name = dev.text.strip().replace('\n', '')
    username = dev.find('a')['href'][1:]
    names.append(f"{name} (@{username})")
    
print(names)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = 'https://www.imdb.com/chart/top/'
sp = requests.get(url).content
sp = BeautifulSoup(sp, 'html.parser')
sp

# %%
selector = "#main > div > span > div > div > div.lister > table > tbody > tr:nth-child(1) > td.titleColumn"
# td.titleColumn at the end of the selector line

# %%
selector = "#main > div > span > div > div > div.lister > table > tbody > tr:nth-child(1) > td.titleColumn"
sp.select(selector)[0].get_text()

# %%
selector2 = "td.titleColumn >a"  # we can even only use "a" as the selector
sp.select(selector2)[0].get_text()

# %%
selector2 = "td.titleColumn >a"
len(sp.select(selector2))

# %%
selector2 = "td.titleColumn >a"
sp.select(selector2)  # add [n] to select a certain element in the list

# %%
for link in sp.select(selector2):
    print(link.get_text())
# Out:
# Les Évadés
# Le Parrain
# The Dark Knight : Le Chevalier noir
# Le Parrain, 2ᵉ partie
# 12 Hommes en colère
# La liste de Schindler
# Le Seigneur des anneaux : Le Retour du roi
# Pulp Fiction
# Le Seigneur des anneaux : La Communauté de l'anneau
# Le Bon, la brute, le truand
# Forrest Gump
# Fight Club
# Le Seigneur des anneaux : Les Deux Tours
# Inception
# L'Empire contre-attaque
# Matrix
# Les affranchis
# Vol au-dessus d'un nid de coucou
# Seven
# La vie est belle
# Les 7 Samouraïs
# Le Silence des agneaux
# Il faut sauver le soldat Ryan
# La cité de Dieu
# Interstellar
# La vie est belle
# La ligne verte
# La guerre des étoiles
# Terminator 2 : Le jugement dernier
# Retour vers le futur
# Le voyage de Chihiro
# Le pianiste
# Psychose
# Parasite
# Léon
# Le Roi Lion
# Gladiator
# American History X
# Les infiltrés
# Whiplash
# Le Prestige
# Usual Suspects
# Casablanca
# Le tombeau des lucioles
# Harakiri
# Intouchables
# Les temps modernes
# Il était une fois dans l'Ouest
# ...

# %%
movie_titles = []
for link in sp.select(selector2):
    movie_titles.append(link.get_text())
movie_titles[0:10]

# %%
movie_df = pd.DataFrame({'Movie_Titles' : movie_titles})
movie_df

# %%
movie_df = pd.DataFrame(movie_titles)
movie_df

# %%
movie_df = pd.DataFrame(movie_titles, column=['movie_titles'])
movie_df

# %%
movie_df = pd.DataFrame({'Movie_Titles' : movie_titles, 'Year_of_Release' : lst_year})
movie_df

# %%
selector_year = "#main > div > span > div > div > div.lister > table > tbody > tr:nth-child(1) > td.titleColumn > span"

# %%
selector_year2 = "td.titleColumn > span"
sp.select(selector_year2)

# %%
selector_year2
for link in sp.select(selector_year2):
    print(link.get_text())

# %%
movie_year = []
for link in sp.select(selector_year2):
    movie_year.append(link.get_text())
movie_year[0:10]
# Out:
# ['(1994)',
#  '(1972)',
#  '(2008)',
#  '(1974)',
#  '(1957)',
#  '(1993)',
#  '(2003)',
#  '(1994)',
#  '(2001)',
#  '(1966)']

# %%
movie_df = pd.DataFrame({'Movie_Titles' : movie_titles, 'Year_of_Release' : movie_year})
movie_df
# Out:
#                             Movie_Titles Year_of_Release
# 0                             Les Évadés          (1994)
# 1                             Le Parrain          (1972)
# 2    The Dark Knight : Le Chevalier noir          (2008)
# 3                  Le Parrain, 2ᵉ partie          (1974)
# 4                    12 Hommes en colère          (1957)
# ..                                   ...             ...
# 245                      Le géant de fer          (1999)
# 246            La couleur des sentiments          (2011)
# 247                              Aladdin          (1992)
# 248                        Dersou Ouzala          (1975)
# 249                 Danse avec les loups          (1990)
#
# [250 rows x 2 columns]

# %%
type(movie_year)

# %%
type(movie_year[0])
