# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
# your code here
import requests

url = 'https://github.com/trending/developers'
html = requests.get('https://github.com/trending/developers').content
html
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n  \n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-0946cdc16f15.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-3946c959759a.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" rel="stylesheet" data-href
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
soup = BeautifulSoup(html, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
#   <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-0946cdc16f15.css" media="all" rel="stylesheet">
#    <link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-3946c959759a.css" media="all" rel="stylesheet">
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here
soup.title
# Out:
# <title>Trending  developers on GitHub today · GitHub</title>

# %%
soup.select('h2')
# Out:
# [<h2 class="sr-only">Footer</h2>]

# %%
soup.title.get_text()
# Out:
# 'Trending  developers on GitHub today · GitHub'

# %%
soup.select('a')[0]
# Out:
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>

# %%
soup.select('a')[0]['href']
# Out:
# '#start-of-content'

# %%
for link in soup.select('a'):
    print(link['href'])
# Out:
# #start-of-content
# https://github.com/
# /signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2Ftrending%2Fdevelopers&source=header
# /features/actions
# /features/packages
# /features/security
# /features/codespaces
# /features/copilot
# /features/code-review
# /features/issues
# /features/discussions
# /features
# https://docs.github.com
# https://skills.github.com/
# https://github.blog
# /enterprise
# /team
# /enterprise/startups
# https://education.github.com
# /solutions/ci-cd/
# https://resources.github.com/devops/
# https://resources.github.com/devops/fundamentals/devsecops/
# /customer-stories
# https://resources.github.com/
# /sponsors
# /readme
# /topics
# /trending
# /collections
# /pricing
#
#
#
#
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# /signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2Ftrending%2Fdevelopers&source=header
# /explore
# /topics
# /trending
# /collections
# /events
# /sponsors/explore
# /explore/email
# ...

# %%
soup.find_all('h1', {'class': 'h3 lh-condensed'})[0]
# Out:
# <h1 class="h3 lh-condensed">
# <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":11986836,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="1b90bdabee974c86cf7c4a7811336a2dce1fb72959549c9dbbcb7af6551cb0dc" data-view-component="true" href="/hwchase17">
#             Harrison Chase
# </a> </h1>

# %%
soup.find('a')['href']
# Out:
# '#start-of-content'

# %%
import re
names = []

items = soup.find_all('h1', {'class': 'h3 lh_condensed'})


for dev in items:
    name = dev.text.strip().replace('\n', '')
    username = dev.find('a')['href'][1:]
    names.append(f"{name} (@{username})")
    
print(names)
# Out:
# []

# %%
items = soup.find_all('h1', {'class': 'h3 lh_condensed'})
items
# this is Kat's method, which is not recommended by Thomas
# Out:
# []

# %%
#selector path for person1: #pa-hwchase17 > div.d-sm-flex.flex-auto > div.col-sm-8.d-md-flex > div:nth-child(1) > h1 > a
# copy the "selector path" of one name, then try to find the rules, is one method that Thomas does not recommend

# %%
soup.select('h1 > a')[0].text.strip()
# Out:
# 'Harrison Chase'

# %%
soup.select('div:nth-child(1) > h1 > a')[2].text.strip()
# Out:
# 'Henrik Rydgård'

# %%
names = soup.select('div:nth-child(1) > h1 > a')
names
# Out:
# [<a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":11986836,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="1b90bdabee974c86cf7c4a7811336a2dce1fb72959549c9dbbcb7af6551cb0dc" data-view-component="true" href="/hwchase17">
#              Harrison Chase
#  </a>,
#  <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":15100009,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="91ce72d685054411d8b3863d74e7cab4e489c938e1bab3e7308724ba7f671842" data-view-component="true" href="/merrymercy">
#              Lianmin Zheng
#  </a>,
# ...

# %%
names = soup.select('div:nth-child(1) > h1 > a')
names[0]
# Out:
# <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":11986836,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="1b90bdabee974c86cf7c4a7811336a2dce1fb72959549c9dbbcb7af6551cb0dc" data-view-component="true" href="/hwchase17">
#             Harrison Chase
# </a>

# %%
lst_names = []

# %%
for name in names:
    name = name.text.strip()
    lst_names.append(name)
print(lst_names)
# Out:
# ['Harrison Chase', 'Lianmin Zheng', 'Henrik Rydgård', 'Peer Richelsen', 'Evgenii Bazhanov', 'Rui Chen', 'oobabooga', 'Michael Bui', 'Fons van der Plas', 'Jerry Liu', 'Matthew Leibowitz', 'Bjorn Lu', 'Sam Clegg', 'Ammar Ahmed', 'Richard Hughes', 'Dan Gohman', 'Mattias Wadman', 'lllyasviel', 'Paweł Bylica', 'Kirat', 'Laurent Mazare', 'Leonid Bugaev', 'Resi Respati', 'Payton Swick', 'Ashley Mannix']

# %%
#selector path for person1-2: #pa-hwchase17 > div.d-sm-flex.flex-auto > div.col-sm-8.d-md-flex > div:nth-child(1) > p

# %%
ids = soup.select('div:nth-child(1) > p')[2].text.strip()
ids
# Out:
# 'merrymercy'

# %%
ids = soup.select('div:nth-child(1) > p')[1]
ids
# Out:
# <p class="f4 text-normal mb-1">
# <a class="Link--secondary" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":11986836,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="1b90bdabee974c86cf7c4a7811336a2dce1fb72959549c9dbbcb7af6551cb0dc" data-view-component="true" href="/hwchase17">
#               hwchase17
# </a> </p>

# %%
ids = soup.select('div:nth-child(1) > p')[3]

# %%
soup.select('a class')['href'][2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2s/stq13gpd5bgc21frj934ykp80000gs/T/ipykernel_26632/288238046.py in <module>
# ----> 1 soup.select('a class')['href'][2]
#
# TypeError: list indices must be integers or slices, not str

# %%
soup.select('a')['href']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2s/stq13gpd5bgc21frj934ykp80000gs/T/ipykernel_26632/320493427.py in <module>
# ----> 1 soup.select('a')['href']
#
# TypeError: list indices must be integers or slices, not str

# %%
lst_ids = []

# %%
for id in ids:
    id = id.text.strip()
    lst_ids.append(id)
print(lst_ids)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/2s/stq13gpd5bgc21frj934ykp80000gs/T/ipykernel_26632/1252242000.py in <module>
#       1 for id in ids:
# ----> 2     id = id.text.strip()
#       3     lst_ids.append(id)
#       4 print(lst_ids)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
username = dev.find('a')['href'][1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2s/stq13gpd5bgc21frj934ykp80000gs/T/ipykernel_26632/763797331.py in <module>
# ----> 1 username = dev.find('a')['href'][1:]
#
# NameError: name 'dev' is not defined

# %%
soup.find('a')['href'][2:9]
# Out:
# 'tart-of'

# %%
#pa-hwchase17 > div.d-sm-flex.flex-auto > div.col-sm-8.d-md-flex > div:nth-child(1) > p

# %%
#pa-hwchase17 > div.d-sm-flex.flex-auto > div.col-sm-8.d-md-flex > div:nth-child(1) > p > a

# %%
div:nth-child(1) > p > a

# %%
soup.select('div:nth-child(1) > p > a')[0]
# Out:
# <a class="Link--secondary" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":11986836,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="1b90bdabee974c86cf7c4a7811336a2dce1fb72959549c9dbbcb7af6551cb0dc" data-view-component="true" href="/hwchase17">
#               hwchase17
# </a>

# %%
ids = soup.select('div:nth-child(1) > p > a')

# %%
lst_ids = []

# %%
for id in ids:
    id = id.text.strip()
    lst_ids.append(id)
print(lst_ids)
# Out:
# ['', 'hwchase17', '', '\n', '\n              hwchase17\n', ' ', '\n', '\n              hwchase17\n', ' ', '\n', '\n              hwchase17\n', ' ', '', 'hwchase17', '', '', 'hwchase17', '', '', 'hwchase17', '']

# %% [markdown]
# ### Thomas's method

# %%
names_raw = soup.select('.lh-condensed')
names_raw
# Out:
# [<a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_cta:Actions;"}' href="/features/actions">
#  <svg aria-hidden="true" class="octicon octicon-workflow color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#  <path d="M1 3a2 2 0 0 1 2-2h6.5a2 2 0 0 1 2 2v6.5a2 2 0 0 1-2 2H7v4.063C7 16.355 7.644 17 8.438 17H12.5v-2.5a2 2 0 0 1 2-2H21a2 2 0 0 1 2 2V21a2 2 0 0 1-2 2h-6.5a2 2 0 0 1-2-2v-2.5H8.437A2.939 2.939 0 0 1 5.5 15.562V11.5H3a2 2 0 0 1-2-2Zm2-.5a.5.5 0 0 0-.5.5v6.5a.5.5 0 0 0 .5.5h6.5a.5.5 0 0 0 .5-.5V3a.5.5 0 0 0-.5-.5ZM14.5 14a.5.5 0 0 0-.5.5V21a.5.5 0 0 0 .5.5H21a.5.5 0 0 0 .5-.5v-6.5a.5.5 0 0 0-.5-.5Z"></path>
#  </svg>
#  <div>
#  <div class="color-fg-default h4">Actions</div>
#          Automate any workflow
# ...

# %%
names_raw[0]
# Out:
# <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_cta:Actions;"}' href="/features/actions">
# <svg aria-hidden="true" class="octicon octicon-workflow color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M1 3a2 2 0 0 1 2-2h6.5a2 2 0 0 1 2 2v6.5a2 2 0 0 1-2 2H7v4.063C7 16.355 7.644 17 8.438 17H12.5v-2.5a2 2 0 0 1 2-2H21a2 2 0 0 1 2 2V21a2 2 0 0 1-2 2h-6.5a2 2 0 0 1-2-2v-2.5H8.437A2.939 2.939 0 0 1 5.5 15.562V11.5H3a2 2 0 0 1-2-2Zm2-.5a.5.5 0 0 0-.5.5v6.5a.5.5 0 0 0 .5.5h6.5a.5.5 0 0 0 .5-.5V3a.5.5 0 0 0-.5-.5ZM14.5 14a.5.5 0 0 0-.5.5V21a.5.5 0 0 0 .5.5H21a.5.5 0 0 0 .5-.5v-6.5a.5.5 0 0 0-.5-.5Z"></path>
# </svg>
# <div>
# <div class="color-fg-default h4">Actions</div>
#         Automate any workflow
# ...

# %%
soup.select('.mb-1')[0]
# Out:
# [<a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_cta:Actions;"}' href="/features/actions">
#  <svg aria-hidden="true" class="octicon octicon-workflow color-fg-subtle mr-3" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
#  <path d="M1 3a2 2 0 0 1 2-2h6.5a2 2 0 0 1 2 2v6.5a2 2 0 0 1-2 2H7v4.063C7 16.355 7.644 17 8.438 17H12.5v-2.5a2 2 0 0 1 2-2H21a2 2 0 0 1 2 2V21a2 2 0 0 1-2 2h-6.5a2 2 0 0 1-2-2v-2.5H8.437A2.939 2.939 0 0 1 5.5 15.562V11.5H3a2 2 0 0 1-2-2Zm2-.5a.5.5 0 0 0-.5.5v6.5a.5.5 0 0 0 .5.5h6.5a.5.5 0 0 0 .5-.5V3a.5.5 0 0 0-.5-.5ZM14.5 14a.5.5 0 0 0-.5.5V21a.5.5 0 0 0 .5.5H21a.5.5 0 0 0 .5-.5v-6.5a.5.5 0 0 0-.5-.5Z"></path>
#  </svg>
#  <div>
#  <div class="color-fg-default h4">Actions</div>
#          Automate any workflow
# ...

# %%
soup.select('.mb-1')[1]
# Out:
# <div class="f6 color-fg-muted text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame mr-1 color-fg-severe" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M9.533.753V.752c.217 2.385 1.463 3.626 2.653 4.81C13.37 6.74 14.498 7.863 14.498 10c0 3.5-3 6-6.5 6S1.5 13.512 1.5 10c0-1.298.536-2.56 1.425-3.286.376-.308.862 0 1.035.454C4.46 8.487 5.581 8.419 6 8c.282-.282.341-.811-.003-1.5C4.34 3.187 7.035.75 8.77.146c.39-.137.726.194.763.607ZM7.998 14.5c2.832 0 5-1.98 5-4.5 0-1.463-.68-2.19-1.879-3.383l-.036-.037c-1.013-1.008-2.3-2.29-2.834-4.434-.322.256-.63.579-.864.953-.432.696-.621 1.58-.046 2.73.473.947.67 2.284-.278 3.232-.61.61-1.545.84-2.403.633a2.79 2.79 0 0 1-1.436-.874A3.198 3.198 0 0 0 3 10c0 2.53 2.164 4.5 4.998 4.5Z"></path>
# </svg>Popular repo</div>

# %%
soup.select('.mb-1')[1].text.strip()
# Out:
# 'Popular repo'

# %% [markdown]
# ### Thomas' method (updated)

# %%
containers = soup.select('.mb-1')

# %%
containers[0]
# Out:
# <p class="f4 text-normal mb-1">
# <a class="Link--secondary" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":11986836,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="1b90bdabee974c86cf7c4a7811336a2dce1fb72959549c9dbbcb7af6551cb0dc" data-view-component="true" href="/hwchase17">
#               hwchase17
# </a> </p>

# %%
containers[5]
# Out:
# <div class="f6 color-fg-muted text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame mr-1 color-fg-severe" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M9.533.753V.752c.217 2.385 1.463 3.626 2.653 4.81C13.37 6.74 14.498 7.863 14.498 10c0 3.5-3 6-6.5 6S1.5 13.512 1.5 10c0-1.298.536-2.56 1.425-3.286.376-.308.862 0 1.035.454C4.46 8.487 5.581 8.419 6 8c.282-.282.341-.811-.003-1.5C4.34 3.187 7.035.75 8.77.146c.39-.137.726.194.763.607ZM7.998 14.5c2.832 0 5-1.98 5-4.5 0-1.463-.68-2.19-1.879-3.383l-.036-.037c-1.013-1.008-2.3-2.29-2.834-4.434-.322.256-.63.579-.864.953-.432.696-.621 1.58-.046 2.73.473.947.67 2.284-.278 3.232-.61.61-1.545.84-2.403.633a2.79 2.79 0 0 1-1.436-.874A3.198 3.198 0 0 0 3 10c0 2.53 2.164 4.5 4.998 4.5Z"></path>
# </svg>Popular repo</div>

# %%
containers[2]
# Out:
# <p class="f4 text-normal mb-1">
# <a class="Link--secondary" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":15100009,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="91ce72d685054411d8b3863d74e7cab4e489c938e1bab3e7308724ba7f671842" data-view-component="true" href="/merrymercy">
#               merrymercy
# </a> </p>

# %%
containers[1].select_one('a').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/2s/stq13gpd5bgc21frj934ykp80000gs/T/ipykernel_26632/779957986.py in <module>
# ----> 1 containers[1].select_one('a').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
containers = soup.select('.mb-1')
usernames = []
for container in containers:
    username = container.select_one('a').text.strip()
    usernames.append(username)
print(usernames)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/2s/stq13gpd5bgc21frj934ykp80000gs/T/ipykernel_26632/4026182388.py in <module>
#       2 usernames = []
#       3 for container in containers:
# ----> 4     username = container.select_one('a').text.strip()
#       5     usernames.append(username)
#       6 print(usernames)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
# your code here

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
# your code here
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = 'https://en.wikipedia.org/wiki/Walt_Disney'
disney = requests.get('https://en.wikipedia.org/wiki/Walt_Disney').content
disney
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Walt Disney - Wikipedia</title>\n<script>document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vecto
# ...

# %%
disney = BeautifulSoup(disney, 'html.parser')
disney
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2s/stq13gpd5bgc21frj934ykp80000gs/T/ipykernel_26632/3007267722.py in <module>
# ----> 1 disney = BeautifulSoup(disney, 'html.parser')
#       2 disney
#
# ~/opt/anaconda3/lib/python3.9/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     310
#     311         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 312             markup = markup.read()
#     313         elif len(markup) <= 256 and (
#     314                 (isinstance(markup, bytes) and not b'<' in markup)
#
# TypeError: 'NoneType' object is not callable

# %%
selector = "#mw-content-text > div.mw-parser-output > table.infobox.biography.vcard > tbody > tr:nth-child(2) > td > a > img"
selector2 = "img"

# %%
selector1.2 = "#mw-content-text > div.mw-parser-output > div:nth-child(13) > div > a > img"

# %%
selector2 = "img"
disney.select(selector2)[2].get_text()

# %%
selector3 = 'td > a > img'
disney.select(selector3)[0].get_text()

# %%
for link in disney.select(selector2):
    print(link.get_text())

# %%
image_link = []
for link in disney.select(selector2):
    image_link.append(link.get_text())
image_link[10]

# %%
# use "a" + [n] + "href" (or a loop) to retrieve the web links  
# for link in soup.findAll('a'):
    print link.get('href')

# %% [markdown]
# ### New endeavors

# %%
containers = disney.select(".image")
containers
# Out:
# [<a class="image" href="/wiki/File:Walt_Disney_1946.JPG"><img alt="Walt Disney 1946.JPG" data-file-height="675" data-file-width="450" decoding="async" height="330" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/330px-Walt_Disney_1946.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/440px-Walt_Disney_1946.JPG 2x" width="220"/></a>,
# ...

# %%
containers[4]['href']
# Out:
# '/wiki/File:Trolley_Troubles_poster.jpg'

# %%
container['href']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/2s/stq13gpd5bgc21frj934ykp80000gs/T/ipykernel_26632/3976425451.py in <module>
# ----> 1 container['href']
#
# ~/opt/anaconda3/lib/python3.9/site-packages/bs4/element.py in __getitem__(self, key)
#    1517         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1518         and throws an exception if it's not there."""
# -> 1519         return self.attrs[key]
#    1520
#    1521     def __iter__(self):
#
# KeyError: 'href'

# %%
lst_image = []
for image in containers:
    image = image['href']
    lst_image.append(image)
print(lst_image)
# Out:
# ['/wiki/File:Walt_Disney_1946.JPG', '/wiki/File:Walt_Disney_1942_signature.svg', '/wiki/File:Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg', '/wiki/File:Walt_Disney_envelope_ca._1921.jpg', '/wiki/File:Trolley_Troubles_poster.jpg', '/wiki/File:Steamboat-willie.jpg', '/wiki/File:Walt_Disney_1935.jpg', '/wiki/File:Walt_Disney_Snow_white_1937_trailer_screenshot_(13).jpg', '/wiki/File:Disney_drawing_goofy.jpg', '/wiki/File:WaltDisneyplansDisneylandDec1954.jpg', '/wiki/File:Walt_disney_portrait_right.jpg', '/wiki/File:Walt_Disney_Grave.JPG', '/wiki/File:Roy_O._Disney_with_Company_at_Press_Conference.jpg', '/wiki/File:DisneySchiphol1951.jpg', '/wiki/File:Disney1968.jpg', '/wiki/File:Disney_Oscar_1953_(cropped).jpg', '/wiki/File:Disneyland_Resort_logo.svg', '/wiki/File:Animation_disc.svg', '/wiki/File:Magic_Kingdom_castle.jpg', '/wiki/File:Blank_television_set.svg']

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
# your code here

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
# your code here

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
# your code here

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
# your code here

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# your code here

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# your code here

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
