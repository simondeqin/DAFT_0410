# %%
conda install streamlit
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/williamfranz/opt/anaconda3
#
#   added / updated specs:
#     - streamlit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20211102.0      |       he9d5cce_0         933 KB
#     altair-4.1.0               |             py_1         484 KB
#     arrow-cpp-8.0.0            |   py39had1886b_0         7.0 MB
#     aws-c-common-0.4.57        |       hb1e8313_1         140 KB
#     aws-c-event-stream-0.1.6   |       h23ab428_5          21 KB
#     aws-checksums-0.1.9        |       hb1e8313_0          47 KB
# ...

# %%
import streamlit as st

# %%
st.title('welcome to Streamlit my first web page')
st.header('Thi is cooooool')
# Out:
# 2023-05-12 09:50:08.132
# ...
#   command:
#
#     streamlit run /Users/williamfranz/opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)
