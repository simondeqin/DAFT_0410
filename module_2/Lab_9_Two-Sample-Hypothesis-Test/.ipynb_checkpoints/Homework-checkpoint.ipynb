# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Independent Sample T-tests
#
# In this challenge, we will be using the Pokemon dataset. Before applying statistical methods to this data, let's first examine the data.
#
# To load the data, run the code below.

# %%
# Run this code:

pokemon = pd.read_csv('pokemon.csv')
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# Let's start off by looking at the `head` function in the cell below.

# %%
# Your code here:

pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %% [markdown]
# The first thing we would like to do is compare the legendary Pokemon to the regular Pokemon. To do this, we should examine the data further. What is the count of legendary vs. non legendary Pokemons?

# %%
# Your code here:

pokemon['Legendary'].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %% [markdown]
# Compute the mean and standard deviation of the total points for both legendary and non-legendary Pokemon.

# %%
# Your code here:

pokemon.groupby('Legendary')['Total'].mean()
# Out:
# Legendary
# False    417.213605
# True     637.384615
# Name: Total, dtype: float64

# %%
pokemon.groupby('Legendary')['Total'].std()
# Out:
# Legendary
# False    106.760417
# True      60.937389
# Name: Total, dtype: float64

# %% [markdown]
# The computation of the mean might give us a clue regarding how the statistical test may turn out; However, it certainly does not prove whether there is a significant difference between the two groups.
#
# In the cell below, use the `ttest_ind` function in `scipy.stats` to compare the the total points for legendary and non-legendary Pokemon. Since we do not have any information about the population, assume the variances are not equal.

# %%
# Your code here:

import scipy as sp
from scipy import stats

# %%
mean_n = 417.213605
stdev_n = 106.760417

mean_l = 637.384615
stdev_l = 60.937389

# %%
# samples_n = [pokemon['Legendary']==False]['Total']
# samples_l = [pokemon['Legendary']]['Total']

# %%
samples_n = pokemon.loc[pokemon['Legendary']==False, 'Total']
samples_n
# Out:
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
#       ...
# 787    494
# 788    304
# 789    514
# 790    245
# 791    535
# Name: Total, Length: 735, dtype: int64

# %%
samples_l = pokemon.loc[pokemon['Legendary']==True, 'Total']
samples_l
# Out:
# 156    580
# 157    580
# 158    580
# 162    680
# 163    780
#       ...
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Name: Total, Length: 65, dtype: int64

# %%
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (6,4)

# %%
plt.hist(samples_n, alpha=.3, color='blue', bins=30, density=True);
plt.hist(samples_l, alpha=.3, color='red', bins=30, density=True);

# %%
stats.ttest_ind(samples_n, samples_l).pvalue
# Out:
# 3.0952457469652825e-52

# %% [markdown]
# What do you conclude from this test? Write your conclusions below.

# %%
# Your conclusions here:

# From the histogram we can already see that the two distributions have very limited overlaps.
# Through the 2-sample ttest, we get a pvalue of 3.0952457469652825e-52, far below 0.05, which clearly rejects the hypothesis

# %% [markdown]
# How about we try to compare the different types of pokemon? In the cell below, list the types of Pokemon from column `Type 1` and the count of each type.

# %%
# Your code here:

list(pokemon['Type 1'].unique())
# Out:
# ['Grass',
#  'Fire',
#  'Water',
#  'Bug',
#  'Normal',
#  'Poison',
#  'Electric',
#  'Ground',
#  'Fairy',
#  'Fighting',
#  'Psychic',
#  'Rock',
#  'Ghost',
#  'Ice',
#  'Dragon',
#  'Dark',
#  'Steel',
#  'Flying']

# %%
pokemon['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# Since water is the largest group of Pokemon, compare the mean and standard deviation of water Pokemon to all other Pokemon.

# %%
# Your code here:

# %% [markdown]
# Perform a hypothesis test comparing the mean of total points for water Pokemon to all non-water Pokemon. Assume the variances are equal.

# %%
# Your code here:

# %% [markdown]
# Write your conclusion below.

# %%
# Your conclusions here:

# %% [markdown]
# # Challenge 2 - Matched Pairs Test
#
# In this challenge we will compare dependent samples of data describing our Pokemon. Our goal is to see whether there is a significant difference between each Pokemon's defense and attack scores. Our hypothesis is that the defense and attack scores are equal. In the cell below, import the `ttest_rel` function from `scipy.stats` and compare the two columns to see if there is a statistically significant difference between them.

# %%
# Your code here:

pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
mean_attack = pokemon['Attack'].mean()
mean_attack
# Out:
# 79.00125

# %%
mean_defense = pokemon['Defense'].mean()
mean_defense
# Out:
# 73.8425

# %%
std_attack = pokemon['Attack'].std()
std_attack
# Out:
# 32.45736586949843

# %%
std_defense = pokemon['Defense'].std()
std_defense
# Out:
# 31.183500559332927

# %%
samples_a = np.random.normal(mean_attack, std_attack, 1000)
samples_d = np.random.normal(mean_defense, std_defense, 1000)

# %%
plt.hist(samples_a, alpha=.3, color='blue', bins=30, density=True)
plt.hist(samples_d, alpha=.3, color='red', bins=30, density=True)
# Out:
# (array([0.00014216, 0.        , 0.00014216, 0.00028433, 0.00042649,
#         0.00071081, 0.00184812, 0.0038384 , 0.00369623, 0.00639733,
#         0.00725031, 0.01137303, 0.01123087, 0.01350547, 0.01350547,
#         0.01123087, 0.01137303, 0.00924059, 0.00980924, 0.00767679,
#         0.006113  , 0.00412272, 0.00284326, 0.00227461, 0.00099514,
#         0.00099514, 0.00042649, 0.00028433, 0.00014216, 0.00028433]),
#  array([-31.65202773, -24.61784145, -17.58365517, -10.54946889,
#          -3.51528261,   3.51890368,  10.55308996,  17.58727624,
#          24.62146252,  31.6556488 ,  38.68983508,  45.72402136,
#          52.75820764,  59.79239392,  66.8265802 ,  73.86076648,
#          80.89495276,  87.92913904,  94.96332532, 101.9975116 ,
#         109.03169788, 116.06588417, 123.10007045, 130.13425673,
#         137.16844301, 144.20262929, 151.23681557, 158.27100185,
#         165.30518813, 172.33937441, 179.37356069]),
#  <BarContainer object of 30 artists>)

# %%
stats.ttest_rel(samples_a, samples_d).pvalue
# Out:
# 5.250619080285575e-05

# %% [markdown]
# If we observe a large p-value, for
# example greater than 0.05 or 0.1 then we cannot reject the null
# hypothesis of identical average scores. If the p-value is smaller
# than the threshold, e.g. 1%, 5% or 10%, then we reject the null
# hypothesis of equal averages.

# %% [markdown]
# Describe the results of the test in the cell below.

# %%
# Your conclusions here:

# since the pvalue is much smaller than 0.05, we can reject the hypothesis that
# the defense and attack scores are equal.

# %% [markdown]
# We are also curious about whether therer is a significant difference between the mean of special defense and the mean of special attack. Perform the hypothesis test in the cell below.

# %%
# Your code here:

# %% [markdown]
# Describe the results of the test in the cell below.

# %%
# Your conclusions here:

# %% [markdown]
# As you may recall, a two sample matched pairs test can also be expressed as a one sample test of the difference between the two dependent columns.
#
# Import the `ttest_1samp` function and perform a one sample t-test of the difference between defense and attack. Test the hypothesis that the difference between the means is zero. Confirm that the results of the test are the same.

# %%
# Your code here:

# %% [markdown]
# # Bonus Challenge - The Chi-Square Test
#
# The Chi-Square test is used to determine whether there is a statistically significant difference in frequencies. In other words, we are testing whether there is a relationship between categorical variables or rather when the variables are independent. This test is an alternative to Fisher's exact test and is used in scenarios where sample sizes are larger. However, with a large enough sample size, both tests produce similar results. Read more about the Chi Squared test [here](https://en.wikipedia.org/wiki/Chi-squared_test).
#
# In the cell below, create a contingency table using `pd.crosstab` comparing whether a Pokemon is legenadary or not and whether the Type 1 of a Pokemon is water or not.

# %%
# Your code here:

pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon['Type bi'] = 'Not Water'
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon.loc[pokemon['Type 1']=='Water', 'Type bi'] = 'Water'
pokemon.head(15)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %%
samples_tp = np.random.choice(['Water', 'Not Water'], 90)
samples_lg = np.random.choice([False, True], 90)

# %%
pd.DataFrame({'result1': samples_tp, 'result2': samples_lg})
# Out:
#       result1  result2
# 0       Water     True
# 1   Not Water    False
# 2       Water     True
# 3   Not Water     True
# 4       Water    False
# ..        ...      ...
# 85      Water     True
# 86  Not Water    False
# 87      Water    False
# 88  Not Water     True
# 89  Not Water    False
#
# [90 rows x 2 columns]

# %% [markdown]
# Perform a chi-squared test using the `chi2_contingency` function in `scipy.stats`. You can read the documentation of the function [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi2_contingency.html).

# %%
# Your code here:

crosstab = stats.contingency.crosstab(samples_tp, samples_lg)
count = crosstab[1]
# Out:
# array([[27, 19],
#        [27, 17]])

# %%
pvalue = stats.chi2_contingency(crosstab[1])[1]
pvalue
# Out:
# 0.9656666366168725

# %% [markdown]
# Based on a 95% confidence, should we reject the null hypothesis?

# %%
# Your answer here:

# The pvalue here is larger than 0.5, which means that (based on a 95% confidence) 
# we cannot reject the null pythothesis that " whether a Pokemon is legenadary or not 
# has some dependence on whether the Type 1 of a Pokemon is water or not."
