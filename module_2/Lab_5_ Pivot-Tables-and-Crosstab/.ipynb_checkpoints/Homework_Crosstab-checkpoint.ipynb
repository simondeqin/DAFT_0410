# %%
# Import Libraries

# %%
import seaborn as sns
import numpy as np
from scipy import stats
import pandas as pd

# %% [markdown]
# ### 1. Import the moovies dataset

# %% [markdown]
# # https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset

# %%
sns.get_dataset_names()
# these are pre-installed dataset inside s
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df0 = sns.load_dataset('titanic')
df0
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df = pd.read_csv('movie_metadata.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 5038                   637.0          NaN                     Comedy|Drama
# 5039                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 5040                     0.0          NaN            Drama|Horror|Thriller
# 5041                   946.0      10443.0             Comedy|Drama|Romance
# 5042                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 5038  ...                  6.0  English   Canada             NaN          NaN
# 5039  ...                359.0  English      USA           TV-14          NaN
# 5040  ...                  3.0  English      USA             NaN       1400.0
# 5041  ...                  9.0  English      USA           PG-13          NaN
# 5042  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 5038      2013.0                  470.0        7.7           NaN
# 5039         NaN                  593.0        7.5         16.00
# 5040      2013.0                    0.0        6.3           NaN
# 5041      2012.0                  719.0        6.3          2.35
# 5042      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 5038                   84
# 5039                32000
# 5040                   16
# 5041                  660
# 5042                  456
#
# [5043 rows x 28 columns]

# %% [markdown]
# ### 2. Use crosstabs to show the number of moovies per country

# %%
pd.crosstab([df['country']], df['country'], values=df['country'], aggfunc=np.sum)
# Out:
# country               Afghanistan                             Argentina  \
# country
# Afghanistan           Afghanistan                                   NaN
# Argentina                     NaN  ArgentinaArgentinaArgentinaArgentina
# Aruba                         NaN                                   NaN
# Australia                     NaN                                   NaN
# Bahamas                       NaN                                   NaN
# ...                           ...                                   ...
# Turkey                        NaN                                   NaN
# UK                            NaN                                   NaN
# USA                           NaN                                   NaN
# United Arab Emirates          NaN                                   NaN
# West Germany                  NaN                                   NaN
#
# country               Aruba  \
# country
# Afghanistan             NaN
# Argentina               NaN
# Aruba                 Aruba
# Australia               NaN
# Bahamas                 NaN
# ...                     ...
# Turkey                  NaN
# UK                      NaN
# USA                     NaN
# United Arab Emirates    NaN
# West Germany            NaN
#
# country                                                       Australia  \
# country
# Afghanistan                                                         NaN
# Argentina                                                           NaN
# Aruba                                                               NaN
# Australia             AustraliaAustraliaAustraliaAustraliaAustraliaA...
# Bahamas                                                             NaN
# ...                                                                 ...
# Turkey                                                              NaN
# UK                                                                  NaN
# USA                                                                 NaN
# United Arab Emirates                                                NaN
# West Germany                                                        NaN
#
# country               Bahamas Belgium Brazil Bulgaria Cambodia Cameroon  ...  \
# country                                                                  ...
# Afghanistan               NaN     NaN    NaN      NaN      NaN      NaN  ...
# Argentina                 NaN     NaN    NaN      NaN      NaN      NaN  ...
# Aruba                     NaN     NaN    NaN      NaN      NaN      NaN  ...
# Australia                 NaN     NaN    NaN      NaN      NaN      NaN  ...
# Bahamas               Bahamas     NaN    NaN      NaN      NaN      NaN  ...
# ...                       ...     ...    ...      ...      ...      ...  ...
# Turkey                    NaN     NaN    NaN      NaN      NaN      NaN  ...
# UK                        NaN     NaN    NaN      NaN      NaN      NaN  ...
# USA                       NaN     NaN    NaN      NaN      NaN      NaN  ...
# United Arab Emirates      NaN     NaN    NaN      NaN      NaN      NaN  ...
# West Germany              NaN     NaN    NaN      NaN      NaN      NaN  ...
#
# country              Spain Sweden Switzerland Taiwan Thailand  Turkey  \
# country
# Afghanistan            NaN    NaN         NaN    NaN      NaN     NaN
# Argentina              NaN    NaN         NaN    NaN      NaN     NaN
# Aruba                  NaN    NaN         NaN    NaN      NaN     NaN
# Australia              NaN    NaN         NaN    NaN      NaN     NaN
# Bahamas                NaN    NaN         NaN    NaN      NaN     NaN
# ...                    ...    ...         ...    ...      ...     ...
# Turkey                 NaN    NaN         NaN    NaN      NaN  Turkey
# UK                     NaN    NaN         NaN    NaN      NaN     NaN
# USA                    NaN    NaN         NaN    NaN      NaN     NaN
# United Arab Emirates   NaN    NaN         NaN    NaN      NaN     NaN
# West Germany           NaN    NaN         NaN    NaN      NaN     NaN
#
# country                                                              UK  \
# country
# Afghanistan                                                         NaN
# Argentina                                                           NaN
# Aruba                                                               NaN
# Australia                                                           NaN
# Bahamas                                                             NaN
# ...                                                                 ...
# Turkey                                                              NaN
# UK                    UKUKUKUKUKUKUKUKUKUKUKUKUKUKUKUKUKUKUKUKUKUKUK...
# USA                                                                 NaN
# United Arab Emirates                                                NaN
# West Germany                                                        NaN
#
# country                                                             USA  \
# country
# Afghanistan                                                         NaN
# Argentina                                                           NaN
# Aruba                                                               NaN
# Australia                                                           NaN
# Bahamas                                                             NaN
# ...                                                                 ...
# Turkey                                                              NaN
# UK                                                                  NaN
# USA                   USAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAU...
# United Arab Emirates                                                NaN
# West Germany                                                        NaN
#
# country               United Arab Emirates  \
# country
# Afghanistan                            NaN
# Argentina                              NaN
# Aruba                                  NaN
# Australia                              NaN
# Bahamas                                NaN
# ...                                    ...
# Turkey                                 NaN
# UK                                     NaN
# USA                                    NaN
# United Arab Emirates  United Arab Emirates
# West Germany                           NaN
#
# country                                       West Germany
# country
# Afghanistan                                            NaN
# Argentina                                              NaN
# Aruba                                                  NaN
# Australia                                              NaN
# Bahamas                                                NaN
# ...                                                    ...
# Turkey                                                 NaN
# UK                                                     NaN
# USA                                                    NaN
# United Arab Emirates                                   NaN
# West Germany          West GermanyWest GermanyWest Germany
#
# [65 rows x 65 columns]

# %%
df['country'].value_counts()
# Out:
# USA              3807
# UK                448
# France            154
# Canada            126
# Germany            97
#                  ...
# Slovakia            1
# Chile               1
# Cambodia            1
# Official site       1
# Philippines         1
# Name: country, Length: 65, dtype: int64

# %% [markdown]
# ### 3. Create a crosstab to show the number of films per director and genre splitted by country

# %% [markdown]
# ### 4. Average duration of filmes grouped by color

# %% [markdown]
# ### 5. Average number of likes per director (assuming that total film's likes are counted as a sum of actor's likes)
